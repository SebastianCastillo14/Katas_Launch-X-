# %% [markdown]
# # Katas Modulo 2

# %%
from IPython.display import Image
Image("CapturaEV1.png")

# %% [markdown]
# #### En este momento no me permitia activar el entorno virtual debido a que la ejecución de Scripts se encontraba deshabilitada, usando la ayuda de la siguiente página logre habilitarlo.
# https://protegermipc.net/2018/11/22/permitir-la-ejecucion-de-scripts-powershell-en-windows-10/

# %%
from IPython.display import Image
Image("CapturaEV2.png")

# %% [markdown]
# ### Logré activar el entorno virtual

# %%
from IPython.display import Image
Image("CapturaEV3.png")

# %% [markdown]
# ### Desactivación he instalación de librerias en entorno virtual exitosa
